# %%
## my token and baseUrl
token = 'TOKEN'
baseUrl = "http://agrodatacube.wur.nl/api/v1/rest"

# %%
## imports
import requests
import pandas as pd
import numpy as np

# %%
## helper functions

def get_fields(year, number):
    field_url = baseUrl+"/fields?output_epsg=4326&page_size="+str(number)+"&page_offset=0&year="+str(year)+"&epsg=4326"

    r = requests.get(url=field_url, headers={'token': token}) 
    if r.status_code != 200:
        print("%d %s" % (r.status_code, r.text))
        exit(-1)

    fields = r.json()
    return fields['features']



def get_soil_code(fieldid):
    soiltypes_url = baseUrl+"/fields/{0}/soiltypes".format(fieldid)
    soiltypes_data = requests.get(url=soiltypes_url, headers={'token': token})
    lijst = soiltypes_data.json()['features']
    
    maxopp = -1
    for el in lijst:
        if el['properties']['perimeter'] > maxopp:
            retval = el['properties']['soilcode']
            maxopp = el['properties']['perimeter']
    
    return retval

# %%
## get some fields
aantalperjaar = 60

allfields = []
for year in range(2009,2018):
    fields = get_fields(year,aantalperjaar)
    for field in fields:
        allfields.append(field)

# %%
## make dataframe

df = pd.DataFrame(columns=['id','x','y','jaar','crop1','crop2','soilcode'])


for field in allfields:
    x = field['geometry']['coordinates'][0][0][0][0]
    y = field['geometry']['coordinates'][0][0][0][1]
    jaar = field['properties']['year']
    crop = field['properties']['crop_name']
    crop_kort = crop.split(',')[0]
    fieldid = field['properties']['fieldid'] 

    soilcode = get_soil_code(fieldid)
    s = pd.Series([fieldid, x, y, jaar, crop_kort, crop, soilcode], df.columns)
    df = df.append(s, ignore_index=True)
df = df.set_index('soilcode')

# %%
## translate soils

def soil_code_to_type(code):
    soiltype_url = baseUrl+"/codes/soilcodes/{0}".format(code)
    soiltype_data = requests.get(soiltype_url, headers={'token': token})
    soil = soiltype_data.json()
    return soil

df = df.reset_index()
df = df.set_index('soilcode')
soilcode_translater = []
for soilcode in df.index.unique():
    try: 
        reqres = soil_code_to_type(soilcode)
        soilname = reqres['features'][0]['properties']['soilname']
        soiltype = reqres['features'][0]['properties']['soiltype']
        soilcode_translater.append({'soilcode': soilcode, 'soilname': soilname, 'soiltype': soiltype})
    except:
        soilcode_translater.append({'soilcode': soilcode, 'soilname': np.nan, 'soiltype': np.nan})

# %%
## make DF

sct = pd.DataFrame(soilcode_translater).set_index('soilcode')
df = df.join(sct, how='left').reset_index().dropna().set_index('id')
del df['soilcode']
del df['crop2']
df['gewas'] = ['Grasland' if 'rasland' in c else c for c in df['crop1']]
del df['crop1']
df2 = df.copy()
df3 = df2.copy()
df2
# Out:
#                 x          y  jaar     soilname              soiltype  \
# id
# 11176    5.696840  52.037825  2009         Zand         Podzolgronden
# 5451888  5.774101  52.055922  2015         Zand         Podzolgronden
# 5536645  5.774101  52.055922  2016         Zand         Podzolgronden
# 6710023  5.774101  52.055922  2017         Zand         Podzolgronden
# 206315   5.708485  51.961387  2009  Zware zavel     Rivierkleigronden
# 815110   5.698066  51.960849  2009  Zware zavel     Rivierkleigronden
# 210111   5.715541  51.961253  2009  Zware zavel     Rivierkleigronden
# 1516956  5.690179  51.958157  2010  Zware zavel     Rivierkleigronden
# 1431518  5.714315  51.961698  2010  Zware zavel     Rivierkleigronden
# 413688   5.622418  51.944088  2009   Geen bodem            Geen bodem
# 1385340  5.629215  51.947201  2010   Geen bodem            Geen bodem
# 1629145  5.619449  51.948304  2011   Geen bodem            Geen bodem
# 800709   5.691278  51.955606  2009   Geen bodem            Geen bodem
# 2732289  5.678582  51.952204  2012   Geen bodem            Geen bodem
#
#                                  gewas
# id
# 11176          Overige natuurterreinen
# 5451888  Natuurterreinen (incl. heide)
# 5536645  Natuurterreinen (incl. heide)
# 6710023  Natuurterreinen (incl. heide)
# 206315                        Grasland
# 815110                        Grasland
# 210111                        Grasland
# 1516956                       Grasland
# 1431518                       Grasland
# 1577721                       Grasland
# 1432807                       Grasland
# 1501375                       Grasland
# 2254790                       Grasland
# 2366343                       Grasland
# 2373457                       Grasland
# 2365002                       Grasland
# 2370426                       Grasland
# 1987082                       Grasland
# 2745871                       Grasland
# 2968796                       Grasland
# 2503553                       Grasland
# 2752922                       Grasland
# 3145545                       Grasland
# 3143092                       Grasland
# 3408277                       Grasland
# 3796833                       Grasland
# 3810893                       Grasland
# 3810892                       Grasland
# 3799313                       Grasland
# 3789652                       Grasland
# ...                                ...
# 2149085                       Grasland
# 2870215                       Grasland
# 3863006                       Grasland
# 4597072                       Grasland
# 4758204                       Grasland
# 6043809                       Grasland
# 210629                        Grasland
# 585045                        Grasland
# 1591020                       Grasland
# 974975                        Grasland
# 2090152                       Grasland
# 2942617                       Grasland
# 3395261                       Grasland
# 4310929                       Grasland
# 4841966                       Grasland
# 5853902                       Grasland
# 5869151                       Grasland
# 6610207                       Grasland
# 6902895                       Grasland
# 1269850                           Mais
# 2256112                           Mais
# 2714261                    Aardappelen
# 3600876                           Mais
# 4419563                           Mais
# 7037858                           Mais
# 413688                        Grasland
# 1385340                       Grasland
# 1629145                       Grasland
# 800709                        Grasland
# 2732289                       Grasland
#
# [535 rows x 6 columns]

# %%
df2['gewas']    = [gewas if gewas in ['Grasland', 'Mais', 'Tarwe'] else 'Overig' for gewas in df2['gewas']]
df2['soiltype'] = [soilt if soilt in ['Podzolgronden', 'Kalkloze zandgronden', 'Zeekleigronden', 
                                      'Dikke eerdgronden', 'Rivierkleigronden', 'Moerige gronden', 
                                      'Veengronden'] else 'Overig' for soilt in df2['soiltype']]
df2['soilname'] = [soiln if soiln in ['Zand', 'Zware zavel', 'Lichte zavel', 'Lichte klei', 'Veen', 
                                      'Moerig op zand', 'Leem'] else 'Overig' for soiln in df2['soilname']]

# %%
for col in df2.columns[2:]:
    print(df2[col].value_counts())
    print()
# Out:
# 2016    60
# 2015    60
# 2014    60
# 2012    60
# 2011    60
# 2017    59
# 2013    59
# 2009    59
# 2010    58
# Name: jaar, dtype: int64
#
# Lichte zavel    253
# Zand            130
# Zware zavel     101
# Overig           43
# Veen              8
# Name: soilname, dtype: int64
#
# Rivierkleigronden       359
# Podzolgronden           110
# Kalkloze zandgronden     44
# Dikke eerdgronden         9
# Veengronden               8
# Overig                    5
# Name: soiltype, dtype: int64
#
# Grasland    410
# Mais         64
# Overig       57
# Tarwe         4
# Name: gewas, dtype: int64

# %%
df2.head()
# Out:
#                 x          y  jaar     soilname           soiltype     gewas
# id
# 11176    5.696840  52.037825  2009         Zand      Podzolgronden    Overig
# 5451888  5.774101  52.055922  2015         Zand      Podzolgronden    Overig
# 5536645  5.774101  52.055922  2016         Zand      Podzolgronden    Overig
# 6710023  5.774101  52.055922  2017         Zand      Podzolgronden    Overig
# 206315   5.708485  51.961387  2009  Zware zavel  Rivierkleigronden  Grasland

# %%
from sklearn import preprocessing

df4 = pd.get_dummies(df2, columns=df2.columns[3:-1])
df4.head()
# Out:
#                 x          y  jaar     gewas  soilname_Lichte zavel  \
# id
# 11176    5.696840  52.037825  2009    Overig                      0
# 5451888  5.774101  52.055922  2015    Overig                      0
# 5536645  5.774101  52.055922  2016    Overig                      0
# 6710023  5.774101  52.055922  2017    Overig                      0
# 206315   5.708485  51.961387  2009  Grasland                      0
#
#          soilname_Overig  soilname_Veen  soilname_Zand  soilname_Zware zavel  \
# id
# 11176                  0              0              1                     0
# 5451888                0              0              1                     0
# 5536645                0              0              1                     0
# 6710023                0              0              1                     0
# 206315                 0              0              0                     1
#
#          soiltype_Dikke eerdgronden  soiltype_Kalkloze zandgronden  \
# id
# 11176                             0                              0
# 5451888                           0                              0
# 5536645                           0                              0
# 6710023                           0                              0
# 206315                            0                              0
#
#          soiltype_Overig  soiltype_Podzolgronden  soiltype_Rivierkleigronden  \
# id
# 11176                  0                       1                           0
# 5451888                0                       1                           0
# 5536645                0                       1                           0
# 6710023                0                       1                           0
# 206315                 0                       0                           1
#
#          soiltype_Veengronden
# id
# 11176                       0
# 5451888                     0
# 5536645                     0
# 6710023                     0
# 206315                      0

# %%
#### # Required Python Packages
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

import pdb

# %%
train_percentage = 0.8
feature_headers  = list(set(df4.columns) - set(['gewas']))
target_header    = 'gewas'


train_x, test_x, train_y, test_y = train_test_split(df4[feature_headers], df4[target_header],
                                                        train_size=train_percentage)
# Out:
# d:\programs\continuum\miniconda3\lib\site-packages\sklearn\model_selection\_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
clf = RandomForestClassifier()
trained_model = clf.fit(train_x, train_y)
predictions = trained_model.predict(test_x)

# %%
res = pd.DataFrame(test_y.copy())
res['pred'] = predictions
res
# Out:
#             gewas      pred
# id
# 3486405  Grasland  Grasland
# 614236     Overig  Grasland
# 1357170  Grasland  Grasland
# 3794943  Grasland  Grasland
# 2827038      Mais      Mais
# 5391024  Grasland  Grasland
# 3233139  Grasland  Grasland
# 674296     Overig    Overig
# 1570814  Grasland  Grasland
# 2315175      Mais  Grasland
# 5733142  Grasland  Grasland
# 6767560      Mais      Mais
# 1787086  Grasland  Grasland
# 3212961  Grasland  Grasland
# 4468643  Grasland  Grasland
# 4093989    Overig  Grasland
# 1625922  Grasland  Grasland
# 2732289  Grasland  Grasland
# 4956221  Grasland  Grasland
# 7037858      Mais      Mais
# 5224779  Grasland  Grasland
# 2288805      Mais    Overig
# 877514     Overig      Mais
# 486941   Grasland  Grasland
# 3707423  Grasland  Grasland
# 6711129      Mais      Mais
# 5375292  Grasland  Grasland
# 92592    Grasland  Grasland
# 6151545  Grasland  Grasland
# 4023794  Grasland  Grasland
# ...           ...       ...
# 7000505  Grasland  Grasland
# 2739366  Grasland  Grasland
# 2748091      Mais      Mais
# 1570884  Grasland  Grasland
# 5209724  Grasland  Grasland
# 2373457  Grasland  Grasland
# 2601832  Grasland  Grasland
